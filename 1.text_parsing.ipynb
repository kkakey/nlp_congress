# %% [markdown]
# ### Sample 10,000 speeches from each session of congress

# %%
def sample_speechids(the_path, seat, sample_size):
    '''function to sample from file of text speeches'''
    import os
    import pandas as pd
    import numpy as np
    
    the_path = the_path
    the_dirs = os.listdir(the_path)

    the_df = pd.DataFrame()
    the_filesnames = []
    #iterate through each directory one by by
    for dir_name in the_dirs:
        if dir_name[0]=="0" or dir_name[0]=="1":
            the_filenames = the_path + "/" + dir_name
            the_filesnames.append(dir_name)

    for line in the_filesnames:
        f = pd.read_csv(filepath_or_buffer = the_path + "/" + line, sep="|", header = None, engine="python")

        df = pd.DataFrame(f)
        df = df.rename(columns=df.iloc[0]).drop(df.index[0])
        df = df[df['chamber']==seat]
        np.random.seed(9)
        sampled_df = df.sample(sample_size, replace=False)
        the_df = the_df.append(sampled_df, ignore_index=True)
    return(the_df)

# %%
samples = sample_speechids("./hein-bound", "S", 10000)

# %%
samples
# Out:
#         speakerid   speech_id   lastname firstname chamber state gender party  \
# 0       103118361  1030189997  MCCONNELL     MITCH       S    KY      M     R
# 1       103112231  1030213776  WELLSTONE      PAUL       S    MN      M     D
# 2       103112321  1030126026   CAMPBELL       BEN       S    CO      M     R
# 3       103112301  1030008162     BREAUX      JOHN       S    LA      M     D
# 4       103108471  1030231926     RIEGLE    DONALD       S    MI      M     D
# ...           ...         ...        ...       ...     ...   ...    ...   ...
# 179995  109112991  1090005859      FRIST   WILLIAM       S    TN      M     R
# 179996  109113441  1090084523     TALENT     JAMES       S    MO      M     R
# 179997  109121541  1090180490      THUNE      JOHN       S    SD      M     R
# 179998  109113921  1090090920     WARNER      JOHN       S    VA      M     R
# 179999  109114511  1090165357    SPECTER     ARLEN       S    PA      M     D
#
#        district nonvoting
# 0           NaN    voting
# 1           NaN    voting
# 2           NaN    voting
# 3           NaN    voting
# 4           NaN    voting
# ...         ...       ...
# 179995      NaN    voting
# 179996      NaN    voting
# 179997      NaN    voting
# 179998      NaN    voting
# 179999      NaN    voting
#
# [180000 rows x 10 columns]

# %%
samples['fullname']=samples['firstname']+' '+samples['lastname']

# %%
#change altnerative party politicans to D/R party they most closely align with
sampled_df.loc[sampled_df['fullname'] == 'BERNARD SANDERS', 'party'] = "D"
sampled_df.loc[sampled_df['fullname'] == 'JOSEPH LIEBERMAN', 'party'] = "D"
sampled_df.loc[sampled_df['fullname'] == 'HARRY BYRD', 'party'] = "D"
sampled_df.loc[sampled_df['fullname'] == 'JAMES JEFFORDS', 'party'] = "D"
sampled_df.loc[sampled_df['fullname'] == 'DEAN BARKLEYS', 'party'] = "D"
sampled_df.loc[sampled_df['fullname'] == 'JAMES BUCKLEY', 'party'] = "R"
speeches_merged.loc[speeches_merged['fullname'] == 'DEAN BARKLEY', 'party'] = "R"

# %%
#Create party label 
party=pd.get_dummies(samples['party'],prefix="party",drop_first=True)
samples[party.columns]=party

# %%
def read_speech(the_path):
    '''function to read in speech files'''
    import os
    import pandas as pd
    
    the_path = the_path
    the_dirs = os.listdir(the_path)

    the_df = pd.DataFrame()

    the_filesnames = []

    #iterate through each directory one by by
    for dir_name in the_dirs:
        if dir_name[0]=="s":
            the_filenames = the_path + "/" + dir_name
            the_filesnames.append(dir_name)

    for line in the_filesnames:
        f = open(the_path + "/" + line, "r", encoding= 'ISO-8859-1')
        speech_id = []
        speech = []
        congress = []
        for line in f:
            if line[0]=="9":
                speech_id.append(line[0:9])
                speech.append(line[10:])            
                congress.append(line[0:2])
            if line[0]=="1":
                speech_id.append(line[0:10])
                speech.append(line[11:])
                congress.append(line[0:3])

        df = pd.DataFrame(list(zip(speech_id, speech, congress)), 
                       columns =['speech_id', 'speech', 'congress'])
        df = df.drop([0]) #remove first row
        the_df = the_df.append(df, ignore_index=True)
        
    return(the_df)

# %%
speeches = read_speech("/Users/kristenakey/Documents/Documents/QMSS/NLP/Project/hein-bound")

# %%
speeches
# Out:
#          speech_id                                             speech congress
# 0        940000002  The Chair lays before the Senate letters of re...       94
# 1        940000003  Mr. President. I ask unanimous consent that th...       94
# 2        940000004                              Is there objection?\n       94
# 3        940000005  Mr. President. reserving the right to objectan...       94
# 4        940000006  The credentials will be laid before the Senate.\n       94
# ...            ...                                                ...      ...
# 4640376  990286727  Mr. Speaker. It is my privilege and pleasure t...       99
# 4640377  990286728  Mr. Speaker. on October 6. 1986. I requested a...       99
# 4640378  990286729  Mr. Speaker. I want to discuss the moneylaunde...       99
# 4640379  990286730  Mr. Speaker. I would like to express my suppor...       99
# 4640380  990286731  Mr. Speaker. I am honored to be completing my ...       99
#
# [4640381 rows x 3 columns]

# %%
#Merge sampled speech IDs and speeches raw
speech_merged = pd.merge(samples, speeches, on=['speech_id'], how='left')

# %%
speech_merged
# Out:
#         speakerid   speech_id   lastname firstname chamber state gender party  \
# 0       103118361  1030189997  MCCONNELL     MITCH       S    KY      M     R
# 1       103112231  1030213776  WELLSTONE      PAUL       S    MN      M     D
# 2       103112321  1030126026   CAMPBELL       BEN       S    CO      M     R
# 3       103112301  1030008162     BREAUX      JOHN       S    LA      M     D
# 4       103108471  1030231926     RIEGLE    DONALD       S    MI      M     D
# ...           ...         ...        ...       ...     ...   ...    ...   ...
# 179995  109112991  1090005859      FRIST   WILLIAM       S    TN      M     R
# 179996  109113441  1090084523     TALENT     JAMES       S    MO      M     R
# 179997  109121541  1090180490      THUNE      JOHN       S    SD      M     R
# 179998  109113921  1090090920     WARNER      JOHN       S    VA      M     R
# 179999  109114511  1090165357    SPECTER     ARLEN       S    PA      M     D
#
#        district nonvoting                                             speech  \
# 0           NaN    voting  Mr. President. I thank the distinguished Senat...
# 1           NaN    voting  Madam President. I say to my colleague from So...
# 2           NaN    voting  Mr. President. I am pleased that the bill I in...
# 3           NaN    voting  Mr. President. I yield back the remainder of m...
# 4           NaN    voting  Mr. President. I rise to commend my friend and...
# ...         ...       ...                                                ...
# 179995      NaN    voting  I ask unanimous consent that the resolution an...
# 179996      NaN    voting  I thank the Senator for his ingenuous unanimou...
# 179997      NaN    voting  Mr. President. today I wish to recognize White...
# 179998      NaN    voting  Mr. President. I now ask further unanimous con...
# 179999      NaN    voting  Mr. President. I ask unanimous consent that at...
#
#        congress
# 0           103
# 1           103
# 2           103
# 3           103
# 4           103
# ...         ...
# 179995      109
# 179996      109
# 179997      109
# 179998      109
# 179999      109
#
# [180000 rows x 12 columns]

# %%
#speech_merged.to_pickle(r'./pickled_data/project-180000_speech_merged.pkl')

# %%
with open("./extended_stop_words.txt", 'r') as input_file:
    ext_stop_words = input_file.read().split(',')
ext_stop_words = [str(i.lower()) for i in ext_stop_words]
ext_stop_words.append(',,')
ext_stop_words.append(',')

# %%
def speech_clean(df):
    '''function to clean/parse speech files'''
    import re
    import nltk
    from nltk.corpus import stopwords
    stop_words = nltk.corpus.stopwords.words('english')
    stop_words.extend(ext_stop_words)
    from nltk.stem import PorterStemmer
    my_stem = PorterStemmer()
    from nltk.stem import WordNetLemmatizer 
    lemmatizer = WordNetLemmatizer()
    dictionary = set(w.lower() for w in nltk.corpus.words.words())
    from tqdm import tqdm

    the_df = pd.DataFrame()
    speechl = pd.Series.tolist(df[['speech']])
    
    #for check
    congressl = pd.Series.tolist(df[['congress']]) # as check
    congressl = [item for sublist in congressl for item in sublist]

    #for check
    speech_idl = pd.Series.tolist(df[['speech_id']]) 
    speech_idl = [item for sublist in speech_idl for item in sublist]

    for line, idnum, session in tqdm(zip(speechl, speech_idl, congressl), total=170000, position=0, leave=True):
        speech_og = []
        for i in line:
            if type(i)==float:
                speech_og.append("NA")
            else:
                i = i[:-1]
                speech_og.append(i)

        #Clean text
        tmp_read =re.sub("[\.]", ' ', str(line)).lower()
        tmp_read = re.sub("['\n']", '', tmp_read)
        tmp_read = re.sub('[^a-zA-Z]+', ' ', tmp_read)

        #Tokenization and remove stop words
        tmp_read = [word for word in tmp_read.split() if word not in stop_words]

            #dictionary words
        dict_read = [word for word in tmp_read if word in dictionary]

        #Stemming
        tmp_read_stm = [my_stem.stem(word) for word in tmp_read]
        dict_read_stm = [my_stem.stem(word) for word in dict_read]

        #Lemminization 
        tmp_read_lem = [lemmatizer.lemmatize(word) for word in tmp_read]
        dict_read_lem = [lemmatizer.lemmatize(word) for word in dict_read]

        #rejoin speeches
        tmp_read = ' '.join(tmp_read)
        tmp_read_stm = ' '.join(tmp_read_stm)
        tmp_read_lem = ' '.join(tmp_read_lem)

        dict_read = ' '.join(dict_read)
        dict_read_stm = ' '.join(dict_read_stm)
        dict_read_lem = ' '.join(dict_read_lem)

        #df
        tmp = pd.DataFrame([speech_og], columns=['original speech'])
        tmp['body'] = tmp_read
        tmp['body_stem'] = tmp_read_stm
        tmp['body_lem'] = tmp_read_lem
        tmp['body_dict'] = dict_read
        tmp['body_dict_stem'] = dict_read_stm
        tmp['body_dict_lem'] = dict_read_lem
        
        #for check
        tmp['congress'] = session
        tmp['speech_id'] = idnum

        the_df = the_df.append(tmp, ignore_index=True)
    return(the_df)
    #the_df.to_csv(r'/Users/kristenakey/Desktop/hein-bound-111.csv', index=False)

# %%
speech_parsed = speech_clean(speech_merged)
# Out:
# 100%|██████████| 180000/180000 [8:59:58<00:00,  5.56it/s]

# %%
speech_parsed
# Out:
#                                           original speech  \
# 0       Mr. President. I thank the distinguished Senat...
# 1       Madam President. I say to my colleague from So...
# 2       Mr. President. I am pleased that the bill I in...
# 3       Mr. President. I yield back the remainder of m...
# 4       Mr. President. I rise to commend my friend and...
# ...                                                   ...
# 179995  I ask unanimous consent that the resolution an...
# 179996  I thank the Senator for his ingenuous unanimou...
# 179997  Mr. President. today I wish to recognize White...
# 179998  Mr. President. I now ask further unanimous con...
# 179999  Mr. President. I ask unanimous consent that at...
#
#                                                      body  \
# 0       mr president thank distinguished senator oklah...
# 1       madam president say colleague south dakota abs...
# 2       mr president pleased bill introduced last apri...
# 3       mr president yield back remainder time suggest...
# 4       mr president rise commend friend colleague sen...
# ...                                                   ...
# 179995  ask unanimous consent resolution preamble agre...
# 179996  thank senator ingenuous unanimous consent requ...
# 179997  mr president today wish recognize white lake i...
# 179998  mr president ask unanimous consent senate proc...
# 179999  mr president ask unanimous consent 5 p tuesday...
#
#                                                 body_stem  \
# 0       mr presid thank distinguish senat oklahoma lea...
# 1       madam presid say colleagu south dakota absolut...
# 2       mr presid pleas bill introduc last april desig...
# 3       mr presid yield back remaind time suggest prev...
# 4       mr presid rise commend friend colleagu senat l...
# ...                                                   ...
# 179995  ask unanim consent resolut preambl agre en blo...
# 179996  thank senat ingenu unanim consent request allo...
# 179997  mr presid today wish recogn white lake indepen...
# 179998  mr presid ask unanim consent senat proceed imm...
# 179999  mr presid ask unanim consent 5 p tuesday augus...
#
#                                                  body_lem  \
# 0       mr president thank distinguished senator oklah...
# 1       madam president say colleague south dakota abs...
# 2       mr president pleased bill introduced last apri...
# 3       mr president yield back remainder time suggest...
# 4       mr president rise commend friend colleague sen...
# ...                                                   ...
# 179995  ask unanimous consent resolution preamble agre...
# 179996  thank senator ingenuous unanimous consent requ...
# 179997  mr president today wish recognize white lake i...
# 179998  mr president ask unanimous consent senate proc...
# 179999  mr president ask unanimous consent 5 p tuesday...
#
#                                                 body_dict  \
# 0       mr president thank distinguished senator oklah...
# 1       madam president say colleague south dakota abs...
# 2       mr president bill last april designate federal...
# 3       mr president yield back remainder time suggest...
# 4       mr president rise commend friend colleague sen...
# ...                                                   ...
# 179995  ask unanimous consent resolution preamble agre...
# 179996  thank senator ingenuous unanimous consent requ...
# 179997  mr president today wish recognize white lake i...
# 179998  mr president ask unanimous consent senate proc...
# 179999  mr president ask unanimous consent p tuesday a...
#
#                                            body_dict_stem  \
# 0       mr presid thank distinguish senat oklahoma lea...
# 1       madam presid say colleagu south dakota absolut...
# 2       mr presid bill last april design feder courtho...
# 3       mr presid yield back remaind time suggest prev...
# 4       mr presid rise commend friend colleagu senat l...
# ...                                                   ...
# 179995  ask unanim consent resolut preambl agre en blo...
# 179996  thank senat ingenu unanim consent request go f...
# 179997  mr presid today wish recogn white lake indepen...
# 179998  mr presid ask unanim consent senat proceed imm...
# 179999  mr presid ask unanim consent p tuesday august ...
#
#                                             body_dict_lem congress    speechid
# 0       mr president thank distinguished senator oklah...      103  1030189997
# 1       madam president say colleague south dakota abs...      103  1030213776
# 2       mr president bill last april designate federal...      103  1030126026
# 3       mr president yield back remainder time suggest...      103  1030008162
# 4       mr president rise commend friend colleague sen...      103  1030231926
# ...                                                   ...      ...         ...
# 179995  ask unanimous consent resolution preamble agre...      109  1090005859
# 179996  thank senator ingenuous unanimous consent requ...      109  1090084523
# 179997  mr president today wish recognize white lake i...      109  1090180490
# 179998  mr president ask unanimous consent senate proc...      109  1090090920
# 179999  mr president ask unanimous consent p tuesday a...      109  1090165357
#
# [180000 rows x 9 columns]

# %%
#speech_parsed.to_pickle(r'./pickled_data/project-180000_speeches_parsed.pkl')

# %%
#rejoin clean/parsed speeches to speech_merged 
speech_c = pd.merge(speech_merged, speech_parsed, left_on=['speech_id', "congress"], right_on=['speech_id', "congress"], how='left')#[['cfscore','seat','Cand.ID','Name']]

# %%
#speech_c.to_pickle(r'./pickled_data/project-180000_speech_c.pkl')

# %% [markdown]
# ### Split speeches from each session of congress into unique dataframes

# %%
speech_c = pd.read_pickle(r'./pickled_data/project-180000_speech_c.pkl')

# %% [markdown]
# i.e df_103 = 103rd congressional speeches
